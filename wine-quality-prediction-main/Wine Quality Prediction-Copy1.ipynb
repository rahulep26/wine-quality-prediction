# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a Pandas dataframe
wine_dataset = pd.read_csv("winequality-red.csv")

# %%
#Shape of the dataset
wine_dataset.shape
# Out:
# (1599, 12)

# %%
#few rows of the dataset
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#statistical measures of the dataset
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Data Analysis and Visualization

# %%
#Number of values for each quality
plt.figure(figsize=(10,8))
sns.countplot(x = wine_dataset["quality"]);

# %%
wine_dataset.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
#volatile acidity vs quality
plt.figure(figsize=(10,8))
sns.barplot(x = wine_dataset.quality, y = wine_dataset["volatile acidity"]);

# %% [markdown]
# Inference we got : volatile acidity inversly proportional to quality

# %%
#citric acid vs quality
plt.figure(figsize=(10,8))
sns.barplot(x = wine_dataset.quality, y = wine_dataset["citric acid"]);

# %%
for columns in wine_dataset.columns:
    sns.barplot(x = wine_dataset.quality, y = wine_dataset[columns])
    plt.figure(figsize = (10,10))
    plt.show();

# %%
for columns in wine_dataset.columns:
    sns.scatterplot(x = wine_dataset.quality, y = wine_dataset[columns])
    plt.figure(figsize = (10,10))
    plt.show();

# %% [raw]
# Correlation Matrix:
# 1. Positive Correlation
# 2. Negative Correlation

# %%
correlation = wine_dataset.corr()
correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(correlation, cbar=True, square=True, fmt = '.1f',annot=True, annot_kws = {"size" : 8},cmap = "Blues");

# %%
for a in range(len(wine_dataset.corr().columns)):
    for b in range(a):
        if abs(wine_dataset.corr().iloc[a,b]) >0.7:
            name = df.corr().columns[a]
            print(name)

# %% [raw]
# Here we write a python program with that we find those features whose correlation number is high, as you see in the program we set the correlation number greater than 0.7 it means if any feature has a correlation value above 0.7 then it was considered as a fully correlated feature, at last, we find that no feature is highly correlated.

# %% [raw]
# Data Preprocessing

# %%
#Seperating data and label
x = wine_dataset.drop("quality", axis = 1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Label Binarization
y = wine_dataset["quality"].apply(lambda y_value:1 if y_value >= 7 else 0)

# %%
#Splitting the data
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2, random_state=3)

# %%
#importing module
from sklearn.preprocessing import MinMaxScaler
# creating normalization object 
norm = MinMaxScaler()
# fit data
norm_fit = norm.fit(X_train)
new_xtrain = norm_fit.transform(X_train)
new_xtest = norm_fit.transform(X_test)
# display values
print(new_xtrain)
# Out:
# [[0.42477876 0.19863014 0.48       ... 0.47244094 0.25766871 0.58461538]
#  [0.6460177  0.31506849 0.66       ... 0.24409449 0.11656442 0.24615385]
#  [0.50442478 0.10273973 0.24       ... 0.37795276 0.17791411 0.67692308]
#  ...
#  [0.38938053 0.19178082 0.43       ... 0.36220472 0.14110429 0.58461538]
#  [0.31858407 0.13013699 0.4        ... 0.4488189  0.19018405 0.43076923]
#  [0.25663717 0.31506849 0.2        ... 0.28346457 0.03680982 0.13846154]]

# %%
new_xtrain.shape
# Out:
# (1279, 11)

# %%
new_xtest.shape
# Out:
# (320, 11)

# %%
new_xtrain.shape
# Out:
# (1279, 11)

# %% [markdown]
# Model : Random Forest Classifier

# %%
#Fitting the model
model = RandomForestClassifier()
model.fit(new_xtrain, Y_train)
# Out:
# RandomForestClassifier()

# %%
#Evaluate the model through accuracy
X_test_predict = model.predict(new_xtest)
test_data_accuracy = accuracy_score(Y_test, X_test_predict)
test_data_accuracy
# Out:
# 0.934375

# %% [markdown]
# Building a Predictive System

# %%
input_data = (7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [0]
# Bad Quality Wine

# %%
from sklearn.metrics import classification_report

# predicting score
rnd_score = model.score(new_xtest,Y_test)
print('score of model is : ',rnd_score)
# display error rate
print('calculating the error')
# calculating mean squared error
rnd_MSE = mean_squared_error(Y_test,X_test_predict)
# calculating root mean squared error
rnd_RMSE = np.sqrt(rnd_MSE)
# display MSE
print('mean squared error is : ',rnd_MSE)
# display RMSE
print('root mean squared error is : ',rnd_RMSE)
print(classification_report(X_test_predict,Y_test))
# Out:
# score of model is :  0.934375
# calculating the error
# mean squared error is :  0.065625
# root mean squared error is :  0.25617376914899
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       294
#            1       0.57      0.81      0.67        26
#
#     accuracy                           0.93       320
#    macro avg       0.77      0.88      0.82       320
# weighted avg       0.95      0.93      0.94       320
